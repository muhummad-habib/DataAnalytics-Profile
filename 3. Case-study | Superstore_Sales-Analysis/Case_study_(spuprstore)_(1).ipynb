# %% [markdown]
# # PANDAS SALES ANALYSIS

# %% [markdown]
# Q1: What is the overall Sales trend?
#
# Q2: What are the Top 10 Products by Sales?
#
# Q3: What are the most Selling Products?
#
# Q4: What is the most preferred Ship Mode?
#
# Q5: Which are the most profitable Category and Sub-Caregory?

# %% [markdown]
# # IMPORT THE LIBRARIES

# %%
# DATA MANIPULATION
import pandas as pd

from datetime import datetime, date

# DATA VISULATION
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # IMPORT DATASET

# %%
data = pd.read_csv('//content/drive/MyDrive/Data-Science/Case_stude (superstore) . csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# Show first five rows of dataset
data.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# Display all columns and rows
# pd.set_option('display.max_columns',None)
# pd.set_option('display.max_rows',None)

# %%
# Show last five rows of dataset
data.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
data.shape
# Out:
# (51290, 21)

# %%
data.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# Now we can do further analysis on our data to answer our questions. Before that, we should see
# if there are any missing values in our data set. To check if there are any missing values in the
# entire data set we use the isnull function, then see if there are any values.
#
# We’re lucky we have such a nice data set and with no missing values. While we won’t focus on it in this post,
# a data scientist will spend their time cleaning (or wrangling ) the data. Since we don’t have any missing
# data, we can start doing further analysis on our data.

# %%
data.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# Next, we can look at some descriptive statistics of the data frame with the describe method.
#
# This shows some descriptive statistics on the data set. Notice, it only shows the statistics on the
# numerical columns.From here you can see the following statistics:
#
# Row count, which aligns to what the shape attribute showed us. The mean, or average. The standard deviation,
# or how spread out the data is. The minimum and maximum value of each column The number of items that fall
# within the first, second, and third percentiles.

# %%
# Generating descriptive statistics summary.
data.describe().round()
# Out:
#        quantity  discount   profit  shipping_cost     year
# count   51290.0   51290.0  51290.0        51290.0  51290.0
# mean        3.0       0.0     29.0           26.0   2013.0
# std         2.0       0.0    174.0           57.0      1.0
# min         1.0       0.0  -6600.0            0.0   2011.0
# 25%         2.0       0.0      0.0            3.0   2012.0
# 50%         3.0       0.0      9.0            8.0   2013.0
# 75%         5.0       0.0     37.0           24.0   2014.0
# max        14.0       1.0   8400.0          934.0   2014.0

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Q1: What is the overall Sales trend?

# %%
data.head(1)
# Out:
#        order_id order_date ship_date       ship_mode    customer_name  \
# 0  AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
#
#     segment        state  country  market  region  ...         category  \
# 0  Consumer  Constantine  Algeria  Africa  Africa  ...  Office Supplies
#
#   sub_category         product_name sales quantity  discount  profit  \
# 0      Storage  Tenex Lockers, Blue   408        2       0.0  106.14
#
#    shipping_cost  order_priority  year
# 0          35.46          Medium  2011
#
# [1 rows x 21 columns]

# %%
data['order_date'].min()
# Out:
# '1/1/2011'

# %%
data['order_date'].max()
# Out:
# '9/9/2014'

# %%
# Replace comma with empty space for sale attribute
data['sales']=data['sales'].str.replace(',','')

# %%
# Change object data tipe into ineger using astype(int)
data['sales']=data['sales'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  int64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
# Convert order_date time object into real date & time using pandas
data['order_date']=pd.to_datetime(data['order_date'])

# %%
# Getting months year from order_date
data['month_year']=data['order_date'].apply(lambda x:x.strftime('%Y-%m'))

# %%
data['month_year']
# Out:
# 0        2011-01
# 1        2011-01
# 2        2011-01
# 3        2011-01
# 4        2011-01
#           ...
# 51285    2014-12
# 51286    2014-12
# 51287    2014-12
# 51288    2014-12
# 51289    2014-12
# Name: month_year, Length: 51290, dtype: object

# %%
# Grouping month_year by sale
data_trend=data.groupby('month_year').sum()['sales'].reset_index()

# %%
data_trend
# Out:
#    month_year   sales
# 0     2011-01   98902
# 1     2011-02   91152
# 2     2011-03  145726
# 3     2011-04  116927
# 4     2011-05  146762
# 5     2011-06  215214
# 6     2011-07  115518
# 7     2011-08  207570
# 8     2011-09  290230
# 9     2011-10  199070
# 10    2011-11  298499
# 11    2011-12  333941
# 12    2012-01  135775
# 13    2012-02  100521
# 14    2012-03  163092
# 15    2012-04  161060
# 16    2012-05  208370
# 17    2012-06  256181
# 18    2012-07  145247
# 19    2012-08  303158
# 20    2012-09  289390
# 21    2012-10  252942
# 22    2012-11  323512
# 23    2012-12  338245
# 24    2013-01  199197
# 25    2013-02  167247
# 26    2013-03  198591
# 27    2013-04  177835
# 28    2013-05  260525
# 29    2013-06  396513
# 30    2013-07  229940
# 31    2013-08  326491
# 32    2013-09  376626
# 33    2013-10  293423
# 34    2013-11  373996
# 35    2013-12  405476
# 36    2014-01  241267
# 37    2014-02  184848
# 38    2014-03  263110
# 39    2014-04  242781
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(data_trend['month_year'],data_trend['sales'],color='#b80045')
plt.xticks(rotation='vertical',size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Q 2 Which are the top 10 product by sales

# %%
# defination of DATA FRAME

# %%
#Grouping product name column

prod_sales= pd.DataFrame(data.groupby('product_name').sum()['sales'])

# %%
prod_sales
# Out:
#                                                     sales
# product_name
# "While you Were Out" Message Book, One Form per...     25
# #10 Gummed Flap White Envelopes, 100/Box               42
# #10 Self-Seal White Envelopes                         109
# #10 White Business Envelopes,4 1/8 x 9 1/2            489
# #10- 4 1/8" x 9 1/2" Recycled Envelopes               285
# ...                                                   ...
# iKross Bluetooth Portable Keyboard + Cell Phone...    479
# iOttie HLCRIO102 Car Mount                            216
# iOttie XL Car Mount                                   224
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...    442
# netTALK DUO VoIP Telephone Service                   1113
#
# [3788 rows x 1 columns]

# %% [markdown]
# # Q3: Which are the most selling product

# %%
# most selling product
most_selling_product= pd.DataFrame(data.groupby('product_name').sum()['quantity'])

# %%
most_selling_product
# Out:
#                                                     quantity
# product_name
# "While you Were Out" Message Book, One Form per...         8
# #10 Gummed Flap White Envelopes, 100/Box                  11
# #10 Self-Seal White Envelopes                             10
# #10 White Business Envelopes,4 1/8 x 9 1/2                32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                   37
# ...                                                      ...
# iKross Bluetooth Portable Keyboard + Cell Phone...        24
# iOttie HLCRIO102 Car Mount                                12
# iOttie XL Car Mount                                       14
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...        29
# netTALK DUO VoIP Telephone Service                        26
#
# [3788 rows x 1 columns]

# %% [markdown]
# # Q4: Which is the most preferred Ship Mode

# %%
most_preferred_ship_mode = pd.DataFrame(data.groupby('ship_mode').sum()['sales'])

# %%
most_preferred_ship_mode
# Out:
#                   sales
# ship_mode
# First Class     1831067
# Same Day         667202
# Second Class    2565747
# Standard Class  7578889

# %%
most_preferred_ship_mode=most_preferred_ship_mode.sort_values('sales',ascending= False)

# %%
most_preferred_ship_mode
# Out:
#                   sales
# ship_mode
# Standard Class  7578889
# Second Class    2565747
# First Class     1831067
# Same Day         667202

# %%
most_preferred_ship_mode_q = pd.DataFrame(data.groupby('ship_mode').sum()['quantity'])

# %%
data.plot(x='ship_mode', y='sales', kind='bar', logy= True)

# %%
most_preferred_ship_mode_q
# Out:
#                 quantity
# ship_mode
# First Class        26039
# Same Day            9230
# Second Class       35724
# Standard Class    107319

# %%
most_preferred_ship_mode =most_preferred_ship_mode.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-33cc4ec2e30c> in <module>()
# ----> 1 most_preferred_ship_mode =most_preferred_ship_mode.sort_values()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
# setting the figure size
plt.figure(figsize=(12,6))
#placing the ship mode
sns.countplot(data['ship_mode'])
plt.show()

# %% [markdown]
# # Q5: Which are the most profitable category and sub-category

# %%
most_profitable = pd.DataFrame(data.groupby('category').sum()['profit'])

# %%
most_profitable

# %%
most_profitable=most_profitable.sort_values('profit',ascending= False)

# %%
most_profitable

# %%
most_profitable_sub = pd.DataFrame(data.groupby('sub_category').sum()['profit'])

# %%
most_profitable_sub

# %%
most_profitable_sub=most_profitable_sub.sort_values('profit',ascending=False)

# %%
most_profitable_sub

# %%
most_profitable_c_s= pd.DataFrame(data.groupby(['category','sub_category']).sum()['profit'])

# %%
most_profitable_c_s

# %%
most_profitable_c_s=most_profitable_c_s.sort_values(['category','sub_category'],ascending=False)

# %%
most_profitable_c_s

# %% [markdown]
# # Extra work

# %%
data[['segment','profit']].head()

# %% [markdown]
# # Now which factor can affect sales by mean values

# %%
data.groupby(["segment"])['profit'].mean()

# %%
plt.xlabel("segment")
plt.ylabel("profit")
plt.bar(data['segment'],data['profit'])
plt.show()

# %%
data.groupby(["ship_mode"])['profit'].mean()

# %%
plt.xlabel("ship_mode")
plt.ylabel("profit")
plt.bar(data['ship_mode'],data['profit'])
plt.show()

# %%
data.groupby(["region"])['profit'].mean()

# %%
plt.xlabel("region")
plt.ylabel("profit")
plt.bar(data['region'],data['profit'])
plt.xticks(rotation='vertical',size=8)
plt.show()
